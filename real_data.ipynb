# %%
import dls

# %%
connectivity_analysis = dls.Gradient(res=0.1)

# %%
DC_train, DC_val = connectivity_analysis.data_to_corr("/home/fs0/bsg097/scratch/Data")

# %%
connectivity_analysis.fit_transform(DC_train, method = 'UMAP', N = 100, g = 2, r = 9, MR = 9)

# %%
connectivity_analysis.vis_DCs()

# %%
connectivity_analysis.vis_grads_left(side='left', idx=0)
